# %% [markdown]
# ## INTRODUCCION A PYTHON

# %% [markdown]
# ## Variables
# ## 1.1 Numericas

# %%
# Variables de tipo entero
a=500
#print(a)

# Decimal
b=5.89
#print(b)

#suma entre variables
suma=a-b
#print(suma)

# Operaciones complejas
c="t"+ " " + "p" + " " + "45"
#print(c)

## Capturar informacion del usuario
#cantidad = input('Ingrese la cantidad solicitada : ')
#print ('La cantidad ingresada es : ', cantidad)

## Verificar tipos de variables
type(a)
type(b)
type(c)
# Out:
# str
